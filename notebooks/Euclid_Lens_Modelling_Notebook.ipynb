# %%
#Environment: /Documents/paltas/.venv/bin/python

# %% [raw]
# config_name='config_Euclid_plus_COSMOS_Test'
# image_folder='/users/holloway/localscratch/Euclid_Lens_Modelling_Project/paltas_data'
# python='/users/holloway/Documents/paltas/.venv/bin/python'
# $python ./paltas/generate.py ./paltas/Configs/Examples/$config_name$affix.py $image_folder --n 10 --tf_record --h5

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl

# %%
image_folder='/users/holloway/localscratch/Euclid_Lens_Modelling_Project/paltas_data'
fig,ax = pl.subplots(2,5,figsize=(10,4))
ax = ax.flatten()
for p_i in range()
