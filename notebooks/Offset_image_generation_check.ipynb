# %%
import sys
sys.path.append('/mnt/zfsusers/hollowayp/paltas')
from plot_image_collage import plot_collage
import matplotlib.pyplot as pl
import numpy as np

# %%
plot_collage('/mnt/zfsusers/hollowayp/paltas/paltas_offset_shear_test/new_version/',3,3)
# Out:
# Will use vmin/vmax of (None, None) and ignore interval/stretch values
# Plotting from npy files
